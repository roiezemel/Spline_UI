# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("C:/Users/OWNER/eclipse-workspace/FRC/src/velocities.csv")

# %%
data.plot()

# %%
data.head()
# Out:
#    Right Speed   Left Speed
# 0    49.987297    50.012703
# 1    49.974594    50.025406
# 2    49.961891    50.038109
# 3    49.949188    50.050812
# 4    49.936486    50.063514

# %%
import numpy as np

# %%
d = np.array(data)

# %%
plt.plot(d[:2,0], d[:2,1])
